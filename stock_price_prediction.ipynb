# %% [markdown]
# DL Project 1: Stock price prediction using LSTMs

# %%
import pandas as pd

df = pd.read_csv('google_stock_price_max.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2004-08-19    2.490664    2.591785    2.390042    2.499133    2.499133
# 1     2004-08-20    2.515820    2.716817    2.503118    2.697639    2.697639
# 2     2004-08-23    2.758411    2.826406    2.716070    2.724787    2.724787
# 3     2004-08-24    2.770615    2.779581    2.579581    2.611960    2.611960
# 4     2004-08-25    2.614201    2.689918    2.587302    2.640104    2.640104
# ...          ...         ...         ...         ...         ...         ...
# 4782  2023-08-18  129.059998  129.830002  127.000000  128.110001  128.110001
# 4783  2023-08-21  127.849998  129.259995  127.160004  128.929993  128.929993
# 4784  2023-08-22  129.130005  130.949997  128.925003  129.690002  129.690002
# 4785  2023-08-23  130.850006  134.070007  130.509995  133.210007  133.210007
# 4786  2023-08-24  134.727005  134.970001  130.300003  130.419998  130.419998
#
#          Volume
# 0     897427216
# 1     458857488
# 2     366857939
# 3     306396159
# 4     184645512
# ...         ...
# 4782   23619400
# 4783   21851100
# 4784   15569400
# 4785   26497000
# 4786   18656000
#
# [4787 rows x 7 columns]

# %%
df = df[['Date', 'Close']]

df
# Out:
#             Date       Close
# 0     2004-08-19    2.499133
# 1     2004-08-20    2.697639
# 2     2004-08-23    2.724787
# 3     2004-08-24    2.611960
# 4     2004-08-25    2.640104
# ...          ...         ...
# 4782  2023-08-18  128.110001
# 4783  2023-08-21  128.929993
# 4784  2023-08-22  129.690002
# 4785  2023-08-23  133.210007
# 4786  2023-08-24  130.419998
#
# [4787 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       2004-08-19
# 1       2004-08-20
# 2       2004-08-23
# 3       2004-08-24
# 4       2004-08-25
#            ...
# 4782    2023-08-18
# 4783    2023-08-21
# 4784    2023-08-22
# 4785    2023-08-23
# 4786    2023-08-24
# Name: Date, Length: 4787, dtype: object

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     2004-08-19    2.499133
# 1     2004-08-20    2.697639
# 2     2004-08-23    2.724787
# 3     2004-08-24    2.611960
# 4     2004-08-25    2.640104
# ...          ...         ...
# 4782  2023-08-18  128.110001
# 4783  2023-08-21  128.929993
# 4784  2023-08-22  129.690002
# 4785  2023-08-23  133.210007
# 4786  2023-08-24  130.419998
#
# [4787 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# <ipython-input-7-f6fc52bb0fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = df['Date'].apply(str_to_datetime)
# 0      2004-08-19
# 1      2004-08-20
# 2      2004-08-23
# 3      2004-08-24
# 4      2004-08-25
#           ...
# 4782   2023-08-18
# 4783   2023-08-21
# 4784   2023-08-22
# 4785   2023-08-23
# 4786   2023-08-24
# Name: Date, Length: 4787, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 2004-08-19    2.499133
# 2004-08-20    2.697639
# 2004-08-23    2.724787
# 2004-08-24    2.611960
# 2004-08-25    2.640104
# ...                ...
# 2023-08-18  128.110001
# 2023-08-21  128.929993
# 2023-08-22  129.690002
# 2023-08-23  133.210007
# 2023-08-24  130.419998
#
# [4787 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2021-03-25',
                                '2022-03-23',
                                n=3)
windowed_df

# def df_to_windowed_df(df, n=3):
#   win_data = pd.DataFrame()
#   win_data['Target Date'] = dates
#   for i in range(n,0,-1):
#     win_data[f'Target-{i}']=df['Close'].shift(i)
#   win_data['Target']=df['Close']
#   return win_data.dropna()

# windowed_df = df_to_windowed_df(df)
# windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2021-03-25  101.929497  102.648003  102.252998  102.218002
# 1    2021-03-26  102.648003  102.252998  102.218002  101.777496
# 2    2021-03-29  102.252998  102.218002  101.777496  102.797501
# 3    2021-03-30  102.218002  101.777496  102.797501  102.777000
# 4    2021-03-31  101.777496  102.797501  102.777000  103.431503
# ..          ...         ...         ...         ...         ...
# 247  2022-03-17  126.740997  129.660507  133.690506  134.600494
# 248  2022-03-18  129.660507  133.690506  134.600494  136.801498
# 249  2022-03-21  133.690506  134.600494  136.801498  136.478500
# 250  2022-03-22  134.600494  136.801498  136.478500  140.277496
# 251  2022-03-23  136.801498  136.478500  140.277496  138.503494
#
# [252 rows x 5 columns]

# %%
windowed_df
# Out:
# Empty DataFrame
# Columns: [Target Date, Target-3, Target-2, Target-1, Target]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_0, *['index', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_1, *['Target Date', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_2, *['Target-3', 'count()', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_3, *['Target-2', 'count()', None], **{})
# chart

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((252,), (252, 3, 1), (252,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 98ms/step - loss: 17833.9922 - mean_absolute_error: 132.9566 - val_loss: 18522.4824 - val_mean_absolute_error: 136.0053
# Epoch 2/100
# 7/7 [==============================] - 0s 9ms/step - loss: 17676.9277 - mean_absolute_error: 132.3651 - val_loss: 18358.1191 - val_mean_absolute_error: 135.3997
# Epoch 3/100
# 7/7 [==============================] - 0s 10ms/step - loss: 17504.1641 - mean_absolute_error: 131.7113 - val_loss: 18156.8457 - val_mean_absolute_error: 134.6544
# Epoch 4/100
# 7/7 [==============================] - 0s 12ms/step - loss: 17296.9590 - mean_absolute_error: 130.9220 - val_loss: 17927.9355 - val_mean_absolute_error: 133.8017
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 17058.4297 - mean_absolute_error: 130.0063 - val_loss: 17644.8770 - val_mean_absolute_error: 132.7397
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 16747.5098 - mean_absolute_error: 128.8087 - val_loss: 17267.2383 - val_mean_absolute_error: 131.3093
# Epoch 7/100
# 7/7 [==============================] - 0s 9ms/step - loss: 16334.9150 - mean_absolute_error: 127.1898 - val_loss: 16753.3770 - val_mean_absolute_error: 129.3375
# Epoch 8/100
# 7/7 [==============================] - 0s 9ms/step - loss: 15757.4307 - mean_absolute_error: 124.8843 - val_loss: 16015.7930 - val_mean_absolute_error: 126.4535
# Epoch 9/100
# 7/7 [==============================] - 0s 9ms/step - loss: 14943.4619 - mean_absolute_error: 121.5623 - val_loss: 15031.4971 - val_mean_absolute_error: 122.4997
# Epoch 10/100
# 7/7 [==============================] - 0s 9ms/step - loss: 13928.7500 - mean_absolute_error: 117.3390 - val_loss: 13889.7734 - val_mean_absolute_error: 117.7459
# Epoch 11/100
# 7/7 [==============================] - 0s 9ms/step - loss: 12688.2363 - mean_absolute_error: 111.8702 - val_loss: 12364.4258 - val_mean_absolute_error: 111.0788
# Epoch 12/100
# 7/7 [==============================] - 0s 9ms/step - loss: 11074.7031 - mean_absolute_error: 104.4260 - val_loss: 10529.5039 - val_mean_absolute_error: 102.4865
# Epoch 13/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9232.2725 - mean_absolute_error: 95.2466 - val_loss: 8571.1641 - val_mean_absolute_error: 92.4414
# Epoch 14/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7367.1221 - mean_absolute_error: 84.9090 - val_loss: 6684.6719 - val_mean_absolute_error: 81.6034
# Epoch 15/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5602.4600 - mean_absolute_error: 73.6623 - val_loss: 4863.3926 - val_mean_absolute_error: 69.5542
# Epoch 16/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3922.6184 - mean_absolute_error: 61.3544 - val_loss: 3274.8999 - val_mean_absolute_error: 57.0046
# Epoch 17/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2529.3567 - mean_absolute_error: 48.6251 - val_loss: 1966.5697 - val_mean_absolute_error: 44.0614
# Epoch 18/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1461.5269 - mean_absolute_error: 35.9647 - val_loss: 1043.4039 - val_mean_absolute_error: 31.9047
# Epoch 19/100
# 7/7 [==============================] - 0s 11ms/step - loss: 727.1548 - mean_absolute_error: 23.9945 - val_loss: 402.8660 - val_mean_absolute_error: 19.4234
# Epoch 20/100
# 7/7 [==============================] - 0s 9ms/step - loss: 316.6848 - mean_absolute_error: 15.4368 - val_loss: 121.5114 - val_mean_absolute_error: 9.8303
# Epoch 21/100
# 7/7 [==============================] - 0s 9ms/step - loss: 173.2857 - mean_absolute_error: 11.6709 - val_loss: 37.6907 - val_mean_absolute_error: 5.1793
# Epoch 22/100
# 7/7 [==============================] - 0s 11ms/step - loss: 160.0953 - mean_absolute_error: 10.5992 - val_loss: 25.1500 - val_mean_absolute_error: 4.1261
# Epoch 23/100
# 7/7 [==============================] - 0s 9ms/step - loss: 169.7257 - mean_absolute_error: 10.3567 - val_loss: 25.1613 - val_mean_absolute_error: 4.1015
# Epoch 24/100
# 7/7 [==============================] - 0s 9ms/step - loss: 166.7845 - mean_absolute_error: 10.3556 - val_loss: 27.0989 - val_mean_absolute_error: 4.3168
# Epoch 25/100
# 7/7 [==============================] - 0s 11ms/step - loss: 156.6807 - mean_absolute_error: 10.5219 - val_loss: 31.6554 - val_mean_absolute_error: 4.7153
# Epoch 26/100
# 7/7 [==============================] - 0s 10ms/step - loss: 155.2196 - mean_absolute_error: 10.6815 - val_loss: 36.1365 - val_mean_absolute_error: 5.0546
# Epoch 27/100
# 7/7 [==============================] - 0s 13ms/step - loss: 152.4810 - mean_absolute_error: 10.8080 - val_loss: 39.6586 - val_mean_absolute_error: 5.3464
# Epoch 28/100
# 7/7 [==============================] - 0s 12ms/step - loss: 150.2911 - mean_absolute_error: 10.6850 - val_loss: 40.9726 - val_mean_absolute_error: 5.4455
# Epoch 29/100
# 7/7 [==============================] - 0s 9ms/step - loss: 148.6516 - mean_absolute_error: 10.6692 - val_loss: 41.0022 - val_mean_absolute_error: 5.4476
# Epoch 30/100
# 7/7 [==============================] - 0s 13ms/step - loss: 146.8684 - mean_absolute_error: 10.5796 - val_loss: 36.8997 - val_mean_absolute_error: 5.1299
# Epoch 31/100
# 7/7 [==============================] - 0s 12ms/step - loss: 145.1917 - mean_absolute_error: 10.4591 - val_loss: 36.9996 - val_mean_absolute_error: 5.1403
# Epoch 32/100
# 7/7 [==============================] - 0s 13ms/step - loss: 144.0711 - mean_absolute_error: 10.4860 - val_loss: 38.0408 - val_mean_absolute_error: 5.2248
# Epoch 33/100
# 7/7 [==============================] - 0s 12ms/step - loss: 141.5568 - mean_absolute_error: 10.3774 - val_loss: 34.4674 - val_mean_absolute_error: 4.9265
# Epoch 34/100
# 7/7 [==============================] - 0s 9ms/step - loss: 140.3445 - mean_absolute_error: 10.1963 - val_loss: 32.2305 - val_mean_absolute_error: 4.7324
# Epoch 35/100
# 7/7 [==============================] - 0s 13ms/step - loss: 134.6380 - mean_absolute_error: 10.1505 - val_loss: 38.3340 - val_mean_absolute_error: 5.2437
# Epoch 36/100
# 7/7 [==============================] - 0s 13ms/step - loss: 127.6121 - mean_absolute_error: 9.8451 - val_loss: 32.7287 - val_mean_absolute_error: 4.7872
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 107.8220 - mean_absolute_error: 9.1329 - val_loss: 46.1928 - val_mean_absolute_error: 5.6497
# Epoch 38/100
# 7/7 [==============================] - 0s 9ms/step - loss: 88.1913 - mean_absolute_error: 8.3598 - val_loss: 31.9429 - val_mean_absolute_error: 4.6624
# Epoch 39/100
# 7/7 [==============================] - 0s 10ms/step - loss: 76.7337 - mean_absolute_error: 7.7442 - val_loss: 28.1514 - val_mean_absolute_error: 4.3375
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 61.1080 - mean_absolute_error: 6.8791 - val_loss: 24.1015 - val_mean_absolute_error: 3.9331
# Epoch 41/100
# 7/7 [==============================] - 0s 9ms/step - loss: 48.2408 - mean_absolute_error: 6.0149 - val_loss: 15.5340 - val_mean_absolute_error: 3.1073
# Epoch 42/100
# 7/7 [==============================] - 0s 10ms/step - loss: 40.8918 - mean_absolute_error: 5.5731 - val_loss: 13.1824 - val_mean_absolute_error: 2.7478
# Epoch 43/100
# 7/7 [==============================] - 0s 9ms/step - loss: 34.0131 - mean_absolute_error: 5.0020 - val_loss: 13.6359 - val_mean_absolute_error: 2.8292
# Epoch 44/100
# 7/7 [==============================] - 0s 12ms/step - loss: 25.3367 - mean_absolute_error: 4.3040 - val_loss: 11.4615 - val_mean_absolute_error: 2.5497
# Epoch 45/100
# 7/7 [==============================] - 0s 11ms/step - loss: 19.8960 - mean_absolute_error: 3.7525 - val_loss: 10.8330 - val_mean_absolute_error: 2.4421
# Epoch 46/100
# 7/7 [==============================] - 0s 9ms/step - loss: 15.5925 - mean_absolute_error: 3.3287 - val_loss: 10.5849 - val_mean_absolute_error: 2.3801
# Epoch 47/100
# 7/7 [==============================] - 0s 9ms/step - loss: 12.2392 - mean_absolute_error: 2.8859 - val_loss: 10.0085 - val_mean_absolute_error: 2.3268
# Epoch 48/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9.2998 - mean_absolute_error: 2.4856 - val_loss: 12.3075 - val_mean_absolute_error: 2.6411
# Epoch 49/100
# 7/7 [==============================] - 0s 9ms/step - loss: 7.2128 - mean_absolute_error: 2.1973 - val_loss: 11.0379 - val_mean_absolute_error: 2.5083
# Epoch 50/100
# 7/7 [==============================] - 0s 11ms/step - loss: 5.6303 - mean_absolute_error: 1.8784 - val_loss: 13.9414 - val_mean_absolute_error: 2.8762
# Epoch 51/100
# 7/7 [==============================] - 0s 9ms/step - loss: 6.4394 - mean_absolute_error: 2.0669 - val_loss: 12.1235 - val_mean_absolute_error: 2.6641
# Epoch 52/100
# 7/7 [==============================] - 0s 9ms/step - loss: 5.2135 - mean_absolute_error: 1.8254 - val_loss: 12.0349 - val_mean_absolute_error: 2.6605
# Epoch 53/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.4666 - mean_absolute_error: 1.6579 - val_loss: 10.0379 - val_mean_absolute_error: 2.3859
# Epoch 54/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.3297 - mean_absolute_error: 1.6411 - val_loss: 10.5027 - val_mean_absolute_error: 2.4613
# Epoch 55/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.6993 - mean_absolute_error: 1.7309 - val_loss: 13.5712 - val_mean_absolute_error: 2.8809
# Epoch 56/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.5177 - mean_absolute_error: 1.6910 - val_loss: 11.1172 - val_mean_absolute_error: 2.5562
# Epoch 57/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7870 - mean_absolute_error: 1.5097 - val_loss: 10.2392 - val_mean_absolute_error: 2.4142
# Epoch 58/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.4278 - mean_absolute_error: 1.6767 - val_loss: 10.1477 - val_mean_absolute_error: 2.4066
# Epoch 59/100
# 7/7 [==============================] - 0s 12ms/step - loss: 3.8315 - mean_absolute_error: 1.5215 - val_loss: 10.6965 - val_mean_absolute_error: 2.5129
# Epoch 60/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6075 - mean_absolute_error: 1.4677 - val_loss: 10.8728 - val_mean_absolute_error: 2.5405
# Epoch 61/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.8032 - mean_absolute_error: 1.5252 - val_loss: 10.3332 - val_mean_absolute_error: 2.4438
# Epoch 62/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6197 - mean_absolute_error: 1.5071 - val_loss: 10.6115 - val_mean_absolute_error: 2.5031
# Epoch 63/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6912 - mean_absolute_error: 1.4931 - val_loss: 11.2629 - val_mean_absolute_error: 2.5974
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7344 - mean_absolute_error: 1.4678 - val_loss: 10.3089 - val_mean_absolute_error: 2.4308
# Epoch 65/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.6182 - mean_absolute_error: 1.4572 - val_loss: 11.3558 - val_mean_absolute_error: 2.6097
# Epoch 66/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.7369 - mean_absolute_error: 1.4892 - val_loss: 10.2877 - val_mean_absolute_error: 2.4250
# Epoch 67/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.4290 - mean_absolute_error: 1.6520 - val_loss: 10.2673 - val_mean_absolute_error: 2.4166
# Epoch 68/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.7535 - mean_absolute_error: 1.5115 - val_loss: 10.5591 - val_mean_absolute_error: 2.4922
# Epoch 69/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.5263 - mean_absolute_error: 1.4473 - val_loss: 11.0976 - val_mean_absolute_error: 2.5819
# Epoch 70/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3854 - mean_absolute_error: 1.4061 - val_loss: 11.1291 - val_mean_absolute_error: 2.5854
# Epoch 71/100
# 7/7 [==============================] - 0s 12ms/step - loss: 3.3348 - mean_absolute_error: 1.4134 - val_loss: 10.7596 - val_mean_absolute_error: 2.5299
# Epoch 72/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.4966 - mean_absolute_error: 1.4394 - val_loss: 11.4633 - val_mean_absolute_error: 2.6265
# Epoch 73/100
# 7/7 [==============================] - 0s 13ms/step - loss: 4.0358 - mean_absolute_error: 1.6059 - val_loss: 12.6773 - val_mean_absolute_error: 2.7759
# Epoch 74/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.2694 - mean_absolute_error: 1.6165 - val_loss: 12.7368 - val_mean_absolute_error: 2.7866
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0696 - mean_absolute_error: 1.6078 - val_loss: 11.3877 - val_mean_absolute_error: 2.6192
# Epoch 76/100
# 7/7 [==============================] - 0s 10ms/step - loss: 3.3753 - mean_absolute_error: 1.4532 - val_loss: 12.1968 - val_mean_absolute_error: 2.7131
# Epoch 77/100
# 7/7 [==============================] - 0s 17ms/step - loss: 3.4192 - mean_absolute_error: 1.4308 - val_loss: 10.4737 - val_mean_absolute_error: 2.4631
# Epoch 78/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.2574 - mean_absolute_error: 1.3698 - val_loss: 10.6645 - val_mean_absolute_error: 2.5063
# Epoch 79/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.4675 - mean_absolute_error: 1.4419 - val_loss: 11.5124 - val_mean_absolute_error: 2.6327
# Epoch 80/100
# 7/7 [==============================] - 0s 13ms/step - loss: 3.4577 - mean_absolute_error: 1.4077 - val_loss: 11.1066 - val_mean_absolute_error: 2.5815
# Epoch 81/100
# 7/7 [==============================] - 0s 17ms/step - loss: 3.5659 - mean_absolute_error: 1.4494 - val_loss: 11.0044 - val_mean_absolute_error: 2.5660
# Epoch 82/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.4022 - mean_absolute_error: 1.4324 - val_loss: 10.9290 - val_mean_absolute_error: 2.5541
# Epoch 83/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.3126 - mean_absolute_error: 1.4073 - val_loss: 10.8518 - val_mean_absolute_error: 2.5410
# Epoch 84/100
# 7/7 [==============================] - 0s 20ms/step - loss: 3.5819 - mean_absolute_error: 1.4740 - val_loss: 11.1938 - val_mean_absolute_error: 2.5922
# Epoch 85/100
# 7/7 [==============================] - 0s 18ms/step - loss: 3.7300 - mean_absolute_error: 1.4764 - val_loss: 11.2350 - val_mean_absolute_error: 2.5965
# Epoch 86/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.5547 - mean_absolute_error: 1.4686 - val_loss: 10.8443 - val_mean_absolute_error: 2.5372
# Epoch 87/100
# 7/7 [==============================] - 0s 17ms/step - loss: 3.5224 - mean_absolute_error: 1.4380 - val_loss: 11.0037 - val_mean_absolute_error: 2.5608
# Epoch 88/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.3175 - mean_absolute_error: 1.3956 - val_loss: 10.3748 - val_mean_absolute_error: 2.4414
# Epoch 89/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.3160 - mean_absolute_error: 1.3949 - val_loss: 12.1562 - val_mean_absolute_error: 2.7099
# Epoch 90/100
# 7/7 [==============================] - 0s 13ms/step - loss: 3.6624 - mean_absolute_error: 1.4677 - val_loss: 11.9280 - val_mean_absolute_error: 2.6793
# Epoch 91/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.5855 - mean_absolute_error: 1.4397 - val_loss: 10.4800 - val_mean_absolute_error: 2.4545
# Epoch 92/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.1978 - mean_absolute_error: 1.3536 - val_loss: 10.4830 - val_mean_absolute_error: 2.4585
# Epoch 93/100
# 7/7 [==============================] - 0s 16ms/step - loss: 3.2385 - mean_absolute_error: 1.3822 - val_loss: 10.3865 - val_mean_absolute_error: 2.4358
# Epoch 94/100
# 7/7 [==============================] - 0s 17ms/step - loss: 3.1575 - mean_absolute_error: 1.3544 - val_loss: 10.3854 - val_mean_absolute_error: 2.4351
# Epoch 95/100
# 7/7 [==============================] - 0s 17ms/step - loss: 3.5190 - mean_absolute_error: 1.4495 - val_loss: 13.2246 - val_mean_absolute_error: 2.8467
# Epoch 96/100
# 7/7 [==============================] - 0s 17ms/step - loss: 3.7642 - mean_absolute_error: 1.4702 - val_loss: 11.7641 - val_mean_absolute_error: 2.6582
# Epoch 97/100
# 7/7 [==============================] - 0s 18ms/step - loss: 3.3694 - mean_absolute_error: 1.3971 - val_loss: 10.3903 - val_mean_absolute_error: 2.4402
# Epoch 98/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.1422 - mean_absolute_error: 1.3590 - val_loss: 12.0392 - val_mean_absolute_error: 2.6873
# Epoch 99/100
# 7/7 [==============================] - 0s 14ms/step - loss: 3.4114 - mean_absolute_error: 1.4056 - val_loss: 15.6527 - val_mean_absolute_error: 3.1811
# Epoch 100/100
# 7/7 [==============================] - 0s 14ms/step - loss: 4.3331 - mean_absolute_error: 1.6943 - val_loss: 11.3624 - val_mean_absolute_error: 2.6081

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 7/7 [==============================] - 1s 3ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 [==============================] - 0s 25ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])
